# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Create a new set of 2,000 random latitudes and longitudes

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %% [markdown]
# ### Get the nearest city using the citipy module

# %%
from citipy import citipy

# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

        # Print the city count to confirm sufficient count.
len(cities)
# Out:
# 753

# %% [markdown]
# ### Perform an API call with the OpenWeatherMap

# %%
# Import the requests library.
import requests

## Import the datetime module from the datetime library.
from datetime import datetime

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d3fe34a1634f05652b89a64616ae194

# %% [markdown]
# ### Retrieve the following information from the API call

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

 # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather['weather'][0]['description']
    
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
       
    # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hasaki
# Processing Record 2 of Set 1 | melendugno
# Processing Record 3 of Set 1 | vardo
# Processing Record 4 of Set 1 | ponta do sol
# Processing Record 5 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 6 of Set 1 | arraial do cabo
# Processing Record 7 of Set 1 | matara
# Processing Record 8 of Set 1 | atuona
# Processing Record 9 of Set 1 | kuala lumpur
# Processing Record 10 of Set 1 | kapaa
# Processing Record 11 of Set 1 | lebu
# Processing Record 12 of Set 1 | severo-kurilsk
# Processing Record 13 of Set 1 | kavaratti
# Processing Record 14 of Set 1 | rivers
# Processing Record 15 of Set 1 | port lavaca
# Processing Record 16 of Set 1 | ahipara
# Processing Record 17 of Set 1 | vila velha
# Processing Record 18 of Set 1 | stanghelle
# Processing Record 19 of Set 1 | jalu
# Processing Record 20 of Set 1 | caravelas
# Processing Record 21 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 22 of Set 1 | cody
# Processing Record 23 of Set 1 | ilulissat
# Processing Record 24 of Set 1 | dragor
# Processing Record 25 of Set 1 | ostrovnoy
# Processing Record 26 of Set 1 | port hardy
# Processing Record 27 of Set 1 | nyurba
# Processing Record 28 of Set 1 | puerto ayora
# Processing Record 29 of Set 1 | narsaq
# Processing Record 30 of Set 1 | jamestown
# Processing Record 31 of Set 1 | nishihara
# Processing Record 32 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 33 of Set 1 | rikitea
# Processing Record 34 of Set 1 | jawhar
# Processing Record 35 of Set 1 | manaure
# Processing Record 36 of Set 1 | vallenar
# Processing Record 37 of Set 1 | torbay
# Processing Record 38 of Set 1 | dillon
# Processing Record 39 of Set 1 | banda aceh
# Processing Record 40 of Set 1 | mananara
# Processing Record 41 of Set 1 | tutoia
# Processing Record 42 of Set 1 | zemio
# Processing Record 43 of Set 1 | yellowknife
# Processing Record 44 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 45 of Set 1 | port alfred
# Processing Record 46 of Set 1 | hilo
# Processing Record 47 of Set 1 | kousseri
# Processing Record 48 of Set 1 | bengkulu
# Processing Record 49 of Set 1 | avarua
# Processing Record 50 of Set 1 | gat
# Processing Record 1 of Set 2 | bredasdorp
# Processing Record 2 of Set 2 | akhmeta
# Processing Record 3 of Set 2 | zaysan
# Processing Record 4 of Set 2 | cherskiy
# Processing Record 5 of Set 2 | toora-khem
# Processing Record 6 of Set 2 | kuopio
# Processing Record 7 of Set 2 | pevek
# Processing Record 8 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 9 of Set 2 | khatanga
# Processing Record 10 of Set 2 | ushuaia
# Processing Record 11 of Set 2 | katangli
# Processing Record 12 of Set 2 | mbanza-ngungu
# Processing Record 13 of Set 2 | dikson
# Processing Record 14 of Set 2 | san cristobal
# Processing Record 15 of Set 2 | punta arenas
# Processing Record 16 of Set 2 | qaanaaq
# Processing Record 17 of Set 2 | shenjiamen
# Processing Record 18 of Set 2 | hermanus
# Processing Record 19 of Set 2 | linjiang
# Processing Record 20 of Set 2 | pangnirtung
# Processing Record 21 of Set 2 | airai
# Processing Record 22 of Set 2 | udachnyy
# Processing Record 23 of Set 2 | rocha
# Processing Record 24 of Set 2 | saint-leu
# Processing Record 25 of Set 2 | srednekolymsk
# Processing Record 26 of Set 2 | hamilton
# Processing Record 27 of Set 2 | barrow
# Processing Record 28 of Set 2 | salta
# Processing Record 29 of Set 2 | kaitangata
# Processing Record 30 of Set 2 | jumla
# Processing Record 31 of Set 2 | ruatoria
# City not found. Skipping...
# Processing Record 32 of Set 2 | belmonte
# Processing Record 33 of Set 2 | anton lizardo
# Processing Record 34 of Set 2 | broome
# Processing Record 35 of Set 2 | tazovskiy
# Processing Record 36 of Set 2 | coquimbo
# Processing Record 37 of Set 2 | busselton
# Processing Record 38 of Set 2 | ribeira grande
# Processing Record 39 of Set 2 | mataura
# Processing Record 40 of Set 2 | ahuimanu
# Processing Record 41 of Set 2 | aykhal
# Processing Record 42 of Set 2 | adre
# Processing Record 43 of Set 2 | fatehpur
# Processing Record 44 of Set 2 | hobart
# Processing Record 45 of Set 2 | port keats
# Processing Record 46 of Set 2 | pisco
# Processing Record 47 of Set 2 | miramar
# Processing Record 48 of Set 2 | albany
# Processing Record 49 of Set 2 | bolungarvik
# City not found. Skipping...
# Processing Record 50 of Set 2 | moose factory
# Processing Record 1 of Set 3 | grand gaube
# Processing Record 2 of Set 3 | sungaipenuh
# Processing Record 3 of Set 3 | wismar
# Processing Record 4 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 5 of Set 3 | wagar
# Processing Record 6 of Set 3 | castro
# Processing Record 7 of Set 3 | luderitz
# Processing Record 8 of Set 3 | riyadh
# Processing Record 9 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 10 of Set 3 | yirol
# City not found. Skipping...
# Processing Record 11 of Set 3 | kemijarvi
# Processing Record 12 of Set 3 | mar del plata
# Processing Record 13 of Set 3 | butaritari
# Processing Record 14 of Set 3 | almaznyy
# Processing Record 15 of Set 3 | lata
# Processing Record 16 of Set 3 | nuuk
# Processing Record 17 of Set 3 | faya
# Processing Record 18 of Set 3 | leh
# Processing Record 19 of Set 3 | klaksvik
# Processing Record 20 of Set 3 | saint george
# Processing Record 21 of Set 3 | kodiak
# Processing Record 22 of Set 3 | bahia blanca
# Processing Record 23 of Set 3 | erenhot
# Processing Record 24 of Set 3 | lagoa
# Processing Record 25 of Set 3 | zhuozhou
# City not found. Skipping...
# Processing Record 26 of Set 3 | fukue
# Processing Record 27 of Set 3 | bluff
# Processing Record 28 of Set 3 | victoria
# Processing Record 29 of Set 3 | tasiilaq
# Processing Record 30 of Set 3 | laguna
# Processing Record 31 of Set 3 | upernavik
# Processing Record 32 of Set 3 | annau
# Processing Record 33 of Set 3 | shizunai
# Processing Record 34 of Set 3 | cortez
# Processing Record 35 of Set 3 | hithadhoo
# Processing Record 36 of Set 3 | maamba
# Processing Record 37 of Set 3 | lavrentiya
# Processing Record 38 of Set 3 | camana
# Processing Record 39 of Set 3 | leningradskiy
# Processing Record 40 of Set 3 | kuryk
# Processing Record 41 of Set 3 | chokurdakh
# Processing Record 42 of Set 3 | sao filipe
# Processing Record 43 of Set 3 | tevriz
# Processing Record 44 of Set 3 | mareeba
# Processing Record 45 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 46 of Set 3 | puerto madryn
# Processing Record 47 of Set 3 | salalah
# Processing Record 48 of Set 3 | riverton
# Processing Record 49 of Set 3 | sao joao da barra
# Processing Record 50 of Set 3 | vaini
# Processing Record 1 of Set 4 | paradwip
# City not found. Skipping...
# Processing Record 2 of Set 4 | krasnoselkup
# Processing Record 3 of Set 4 | ambanja
# Processing Record 4 of Set 4 | sao raimundo das mangabeiras
# Processing Record 5 of Set 4 | staryy krym
# Processing Record 6 of Set 4 | pitimbu
# Processing Record 7 of Set 4 | cabo san lucas
# Processing Record 8 of Set 4 | bambous virieux
# Processing Record 9 of Set 4 | tura
# Processing Record 10 of Set 4 | songjianghe
# Processing Record 11 of Set 4 | husavik
# Processing Record 12 of Set 4 | provideniya
# Processing Record 13 of Set 4 | ciudad bolivar
# Processing Record 14 of Set 4 | zhongxing
# Processing Record 15 of Set 4 | quechultenango
# Processing Record 16 of Set 4 | deputatskiy
# Processing Record 17 of Set 4 | yar-sale
# Processing Record 18 of Set 4 | dubna
# Processing Record 19 of Set 4 | rawson
# Processing Record 20 of Set 4 | montgomery
# Processing Record 21 of Set 4 | kahului
# Processing Record 22 of Set 4 | morehead
# Processing Record 23 of Set 4 | east london
# Processing Record 24 of Set 4 | bethel
# Processing Record 25 of Set 4 | katima mulilo
# Processing Record 26 of Set 4 | ituporanga
# Processing Record 27 of Set 4 | cape town
# Processing Record 28 of Set 4 | fairbanks
# Processing Record 29 of Set 4 | kieta
# Processing Record 30 of Set 4 | derzhavinsk
# Processing Record 31 of Set 4 | semey
# Processing Record 32 of Set 4 | mahon
# Processing Record 33 of Set 4 | chicama
# Processing Record 34 of Set 4 | lompoc
# Processing Record 35 of Set 4 | pochutla
# Processing Record 36 of Set 4 | saskylakh
# Processing Record 37 of Set 4 | kingston
# Processing Record 38 of Set 4 | arlit
# Processing Record 39 of Set 4 | high level
# Processing Record 40 of Set 4 | nizwa
# Processing Record 41 of Set 4 | pacific grove
# Processing Record 42 of Set 4 | christchurch
# Processing Record 43 of Set 4 | warqla
# City not found. Skipping...
# Processing Record 44 of Set 4 | iquique
# Processing Record 45 of Set 4 | carnarvon
# Processing Record 46 of Set 4 | clyde river
# Processing Record 47 of Set 4 | obluche
# City not found. Skipping...
# Processing Record 48 of Set 4 | sitka
# Processing Record 49 of Set 4 | port shepstone
# Processing Record 50 of Set 4 | westport
# Processing Record 1 of Set 5 | estelle
# Processing Record 2 of Set 5 | belyy yar
# Processing Record 3 of Set 5 | quzhou
# Processing Record 4 of Set 5 | ashqelon
# Processing Record 5 of Set 5 | kota bahru
# Processing Record 6 of Set 5 | kirensk
# Processing Record 7 of Set 5 | ridgetown
# Processing Record 8 of Set 5 | turukhansk
# Processing Record 9 of Set 5 | padang
# Processing Record 10 of Set 5 | atherton
# Processing Record 11 of Set 5 | canavieiras
# Processing Record 12 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 13 of Set 5 | sioux lookout
# Processing Record 14 of Set 5 | salinopolis
# Processing Record 15 of Set 5 | mullaitivu
# City not found. Skipping...
# Processing Record 16 of Set 5 | warrnambool
# Processing Record 17 of Set 5 | ullal
# Processing Record 18 of Set 5 | staryy nadym
# Processing Record 19 of Set 5 | thompson
# Processing Record 20 of Set 5 | dabola
# Processing Record 21 of Set 5 | haines junction
# Processing Record 22 of Set 5 | galesburg
# Processing Record 23 of Set 5 | chuy
# Processing Record 24 of Set 5 | longyearbyen
# Processing Record 25 of Set 5 | walvis bay
# Processing Record 26 of Set 5 | okhotsk
# Processing Record 27 of Set 5 | nanortalik
# Processing Record 28 of Set 5 | phrai bung
# City not found. Skipping...
# Processing Record 29 of Set 5 | takoradi
# Processing Record 30 of Set 5 | charlestown
# Processing Record 31 of Set 5 | charters towers
# Processing Record 32 of Set 5 | hobyo
# Processing Record 33 of Set 5 | tabas
# Processing Record 34 of Set 5 | gibara
# Processing Record 35 of Set 5 | san luis
# Processing Record 36 of Set 5 | new norfolk
# Processing Record 37 of Set 5 | mayuge
# Processing Record 38 of Set 5 | lugazi
# Processing Record 39 of Set 5 | fortuna
# Processing Record 40 of Set 5 | silanga
# Processing Record 41 of Set 5 | constitucion
# Processing Record 42 of Set 5 | mattru
# Processing Record 43 of Set 5 | vila franca do campo
# Processing Record 44 of Set 5 | ikeda
# Processing Record 45 of Set 5 | atambua
# Processing Record 46 of Set 5 | eyl
# Processing Record 47 of Set 5 | geraldton
# Processing Record 48 of Set 5 | iqaluit
# Processing Record 49 of Set 5 | umtata
# Processing Record 50 of Set 5 | naryan-mar
# Processing Record 1 of Set 6 | tanout
# Processing Record 2 of Set 6 | ocos
# Processing Record 3 of Set 6 | severobaykalsk
# Processing Record 4 of Set 6 | barawe
# City not found. Skipping...
# Processing Record 5 of Set 6 | longlac
# City not found. Skipping...
# Processing Record 6 of Set 6 | makakilo city
# Processing Record 7 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 8 of Set 6 | zeya
# Processing Record 9 of Set 6 | verin
# Processing Record 10 of Set 6 | cayenne
# Processing Record 11 of Set 6 | rangpur
# Processing Record 12 of Set 6 | tabou
# Processing Record 13 of Set 6 | xining
# Processing Record 14 of Set 6 | coihaique
# Processing Record 15 of Set 6 | nikolskoye
# Processing Record 16 of Set 6 | itoman
# Processing Record 17 of Set 6 | mao
# Processing Record 18 of Set 6 | heihe
# Processing Record 19 of Set 6 | palmer
# Processing Record 20 of Set 6 | bronkhorstspruit
# Processing Record 21 of Set 6 | talcahuano
# Processing Record 22 of Set 6 | suchdol nad luznici
# Processing Record 23 of Set 6 | finschhafen
# Processing Record 24 of Set 6 | lasa
# Processing Record 25 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 26 of Set 6 | katsuura
# Processing Record 27 of Set 6 | almeirim
# Processing Record 28 of Set 6 | necochea
# Processing Record 29 of Set 6 | ust-kulom
# Processing Record 30 of Set 6 | ixtapa
# Processing Record 31 of Set 6 | san patricio
# Processing Record 32 of Set 6 | nizhniy kuranakh
# Processing Record 33 of Set 6 | sampit
# Processing Record 34 of Set 6 | adrar
# Processing Record 35 of Set 6 | sept-iles
# Processing Record 36 of Set 6 | isla mujeres
# Processing Record 37 of Set 6 | sidney
# Processing Record 38 of Set 6 | labuhan
# Processing Record 39 of Set 6 | marawi
# Processing Record 40 of Set 6 | nouadhibou
# Processing Record 41 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 42 of Set 6 | ayan
# Processing Record 43 of Set 6 | flinders
# Processing Record 44 of Set 6 | san policarpo
# Processing Record 45 of Set 6 | palana
# Processing Record 46 of Set 6 | kununurra
# Processing Record 47 of Set 6 | scottsbluff
# Processing Record 48 of Set 6 | hervey bay
# Processing Record 49 of Set 6 | port elizabeth
# Processing Record 50 of Set 6 | diebougou
# Processing Record 1 of Set 7 | coari
# Processing Record 2 of Set 7 | kulhudhuffushi
# Processing Record 3 of Set 7 | honiara
# Processing Record 4 of Set 7 | metehara
# City not found. Skipping...
# Processing Record 5 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 6 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 7 of Set 7 | georgetown
# Processing Record 8 of Set 7 | paamiut
# Processing Record 9 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 10 of Set 7 | corinto
# Processing Record 11 of Set 7 | lodja
# Processing Record 12 of Set 7 | chapais
# Processing Record 13 of Set 7 | mount isa
# Processing Record 14 of Set 7 | kibala
# Processing Record 15 of Set 7 | tongliao
# Processing Record 16 of Set 7 | esperance
# Processing Record 17 of Set 7 | sunland park
# Processing Record 18 of Set 7 | the valley
# Processing Record 19 of Set 7 | itaituba
# Processing Record 20 of Set 7 | juifang
# City not found. Skipping...
# Processing Record 21 of Set 7 | oistins
# Processing Record 22 of Set 7 | huilong
# Processing Record 23 of Set 7 | khonuu
# City not found. Skipping...
# Processing Record 24 of Set 7 | general roca
# Processing Record 25 of Set 7 | ngukurr
# City not found. Skipping...
# Processing Record 26 of Set 7 | sassandra
# Processing Record 27 of Set 7 | ossora
# Processing Record 28 of Set 7 | freeport
# Processing Record 29 of Set 7 | beringovskiy
# Processing Record 30 of Set 7 | angermunde
# Processing Record 31 of Set 7 | lakatoro
# Processing Record 32 of Set 7 | higuey
# City not found. Skipping...
# Processing Record 33 of Set 7 | tuktoyaktuk
# Processing Record 34 of Set 7 | athens
# Processing Record 35 of Set 7 | huzhou
# Processing Record 36 of Set 7 | portland
# Processing Record 37 of Set 7 | verkhoyansk
# Processing Record 38 of Set 7 | bacuit
# City not found. Skipping...
# Processing Record 39 of Set 7 | taltal
# Processing Record 40 of Set 7 | san vicente
# Processing Record 41 of Set 7 | la ronge
# Processing Record 42 of Set 7 | maragogi
# Processing Record 43 of Set 7 | meulaboh
# Processing Record 44 of Set 7 | panique
# Processing Record 45 of Set 7 | tilichiki
# Processing Record 46 of Set 7 | dudinka
# Processing Record 47 of Set 7 | san rafael
# Processing Record 48 of Set 7 | ostersund
# Processing Record 49 of Set 7 | kavieng
# Processing Record 50 of Set 7 | novikovo
# Processing Record 1 of Set 8 | araouane
# Processing Record 2 of Set 8 | tiksi
# Processing Record 3 of Set 8 | sidrolandia
# Processing Record 4 of Set 8 | chitungwiza
# Processing Record 5 of Set 8 | andenes
# Processing Record 6 of Set 8 | vestmanna
# Processing Record 7 of Set 8 | neryungri
# Processing Record 8 of Set 8 | marseille
# Processing Record 9 of Set 8 | oudtshoorn
# Processing Record 10 of Set 8 | nenagh
# Processing Record 11 of Set 8 | kolokani
# Processing Record 12 of Set 8 | northam
# Processing Record 13 of Set 8 | henties bay
# Processing Record 14 of Set 8 | suntar
# Processing Record 15 of Set 8 | norman wells
# Processing Record 16 of Set 8 | leiyang
# Processing Record 17 of Set 8 | mahebourg
# Processing Record 18 of Set 8 | gigmoto
# Processing Record 19 of Set 8 | kemin
# Processing Record 20 of Set 8 | saint-philippe
# Processing Record 21 of Set 8 | kuminskiy
# Processing Record 22 of Set 8 | puerto escondido
# Processing Record 23 of Set 8 | saint anthony
# Processing Record 24 of Set 8 | rio gallegos
# Processing Record 25 of Set 8 | syumsi
# Processing Record 26 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 27 of Set 8 | asau
# Processing Record 28 of Set 8 | jinchang
# Processing Record 29 of Set 8 | iisalmi
# Processing Record 30 of Set 8 | wattens
# Processing Record 31 of Set 8 | dzerzhinskoye
# Processing Record 32 of Set 8 | marsa matruh
# Processing Record 33 of Set 8 | titay
# Processing Record 34 of Set 8 | spirit river
# Processing Record 35 of Set 8 | jiuquan
# Processing Record 36 of Set 8 | bathsheba
# Processing Record 37 of Set 8 | filadelfia
# Processing Record 38 of Set 8 | chagda
# City not found. Skipping...
# Processing Record 39 of Set 8 | paredon
# Processing Record 40 of Set 8 | te anau
# Processing Record 41 of Set 8 | waipawa
# Processing Record 42 of Set 8 | samarai
# Processing Record 43 of Set 8 | sobolevo
# Processing Record 44 of Set 8 | djenne
# Processing Record 45 of Set 8 | havoysund
# Processing Record 46 of Set 8 | monte patria
# Processing Record 47 of Set 8 | denpasar
# Processing Record 48 of Set 8 | muli
# Processing Record 49 of Set 8 | tsogni
# Processing Record 50 of Set 8 | mathathane
# Processing Record 1 of Set 9 | murray
# Processing Record 2 of Set 9 | touros
# Processing Record 3 of Set 9 | salekhard
# Processing Record 4 of Set 9 | kruisfontein
# Processing Record 5 of Set 9 | san andres
# Processing Record 6 of Set 9 | polis
# Processing Record 7 of Set 9 | samaipata
# Processing Record 8 of Set 9 | tawkar
# City not found. Skipping...
# Processing Record 9 of Set 9 | lerwick
# Processing Record 10 of Set 9 | kawalu
# Processing Record 11 of Set 9 | alghero
# Processing Record 12 of Set 9 | aksu
# Processing Record 13 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 14 of Set 9 | bowen
# Processing Record 15 of Set 9 | elko
# Processing Record 16 of Set 9 | sidi ali
# Processing Record 17 of Set 9 | vestmannaeyjar
# Processing Record 18 of Set 9 | mangan
# Processing Record 19 of Set 9 | ancud
# Processing Record 20 of Set 9 | borodyanka
# Processing Record 21 of Set 9 | vyartsilya
# Processing Record 22 of Set 9 | college
# Processing Record 23 of Set 9 | vostok
# Processing Record 24 of Set 9 | aasiaat
# Processing Record 25 of Set 9 | banovici
# Processing Record 26 of Set 9 | diffa
# Processing Record 27 of Set 9 | puntarenas
# Processing Record 28 of Set 9 | gao
# Processing Record 29 of Set 9 | mogadishu
# Processing Record 30 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 31 of Set 9 | primorsk
# Processing Record 32 of Set 9 | faanui
# Processing Record 33 of Set 9 | beloha
# Processing Record 34 of Set 9 | boddam
# Processing Record 35 of Set 9 | skaudvile
# Processing Record 36 of Set 9 | harper
# Processing Record 37 of Set 9 | rumonge
# Processing Record 38 of Set 9 | cabinda
# Processing Record 39 of Set 9 | simao
# Processing Record 40 of Set 9 | bojaya
# City not found. Skipping...
# Processing Record 41 of Set 9 | hay river
# Processing Record 42 of Set 9 | jabiru
# City not found. Skipping...
# Processing Record 43 of Set 9 | port hedland
# Processing Record 44 of Set 9 | bundaberg
# Processing Record 45 of Set 9 | souillac
# Processing Record 46 of Set 9 | rauma
# Processing Record 47 of Set 9 | sydney
# Processing Record 48 of Set 9 | carutapera
# Processing Record 49 of Set 9 | cadiz
# Processing Record 50 of Set 9 | kondinskoye
# Processing Record 1 of Set 10 | borisoglebsk
# Processing Record 2 of Set 10 | santa rosa
# Processing Record 3 of Set 10 | aklavik
# Processing Record 4 of Set 10 | anadyr
# Processing Record 5 of Set 10 | dukat
# Processing Record 6 of Set 10 | huazolotitlan
# City not found. Skipping...
# Processing Record 7 of Set 10 | paranaiba
# Processing Record 8 of Set 10 | willmar
# Processing Record 9 of Set 10 | faro
# Processing Record 10 of Set 10 | vanderhoof
# Processing Record 11 of Set 10 | saint-joseph
# Processing Record 12 of Set 10 | cap-aux-meules
# Processing Record 13 of Set 10 | yerbogachen
# Processing Record 14 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 15 of Set 10 | itupiranga
# Processing Record 16 of Set 10 | hofn
# Processing Record 17 of Set 10 | fort nelson
# Processing Record 18 of Set 10 | berlevag
# Processing Record 19 of Set 10 | bajo baudo
# City not found. Skipping...
# Processing Record 20 of Set 10 | cidreira
# Processing Record 21 of Set 10 | saldanha
# Processing Record 22 of Set 10 | berga
# Processing Record 23 of Set 10 | kant
# Processing Record 24 of Set 10 | vanimo
# Processing Record 25 of Set 10 | fraga
# Processing Record 26 of Set 10 | dingle
# Processing Record 27 of Set 10 | kijang
# Processing Record 28 of Set 10 | ambilobe
# Processing Record 29 of Set 10 | uarini
# Processing Record 30 of Set 10 | mahajanga
# Processing Record 31 of Set 10 | kiunga
# Processing Record 32 of Set 10 | williams lake
# Processing Record 33 of Set 10 | zhezkazgan
# Processing Record 34 of Set 10 | otautau
# Processing Record 35 of Set 10 | jahrom
# City not found. Skipping...
# Processing Record 36 of Set 10 | agaro
# Processing Record 37 of Set 10 | matagami
# Processing Record 38 of Set 10 | rajgarh
# Processing Record 39 of Set 10 | saint-augustin
# Processing Record 40 of Set 10 | betanzos
# Processing Record 41 of Set 10 | dasoguz
# Processing Record 42 of Set 10 | joao pinheiro
# Processing Record 43 of Set 10 | mount gambier
# Processing Record 44 of Set 10 | presidencia roque saenz pena
# Processing Record 45 of Set 10 | maghama
# City not found. Skipping...
# Processing Record 46 of Set 10 | bambanglipuro
# Processing Record 47 of Set 10 | kloulklubed
# Processing Record 48 of Set 10 | codrington
# Processing Record 49 of Set 10 | makokou
# Processing Record 50 of Set 10 | jasper
# Processing Record 1 of Set 11 | chibombo
# Processing Record 2 of Set 11 | miranorte
# City not found. Skipping...
# Processing Record 3 of Set 11 | felidhoo
# City not found. Skipping...
# Processing Record 4 of Set 11 | konevo
# Processing Record 5 of Set 11 | umba
# Processing Record 6 of Set 11 | brownwood
# Processing Record 7 of Set 11 | labuan
# Processing Record 8 of Set 11 | putina
# Processing Record 9 of Set 11 | rio cuarto
# Processing Record 10 of Set 11 | shakawe
# Processing Record 11 of Set 11 | launceston
# Processing Record 12 of Set 11 | alice springs
# Processing Record 13 of Set 11 | namibe
# Processing Record 14 of Set 11 | catia la mar
# Processing Record 15 of Set 11 | ulm
# Processing Record 16 of Set 11 | louga
# Processing Record 17 of Set 11 | asosa
# Processing Record 18 of Set 11 | nurota
# Processing Record 19 of Set 11 | sola
# Processing Record 20 of Set 11 | mitsamiouli
# Processing Record 21 of Set 11 | avera
# Processing Record 22 of Set 11 | rakai
# Processing Record 23 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 24 of Set 11 | half moon bay
# Processing Record 25 of Set 11 | vazante
# Processing Record 26 of Set 11 | cabedelo
# Processing Record 27 of Set 11 | khor
# Processing Record 28 of Set 11 | giresun
# Processing Record 29 of Set 11 | issenye
# Processing Record 30 of Set 11 | novoilinsk
# Processing Record 31 of Set 11 | sarai sidhu
# Processing Record 32 of Set 11 | naze
# Processing Record 33 of Set 11 | rundu
# Processing Record 34 of Set 11 | olafsvik
# Processing Record 35 of Set 11 | abonnema
# Processing Record 36 of Set 11 | ulladulla
# Processing Record 37 of Set 11 | waingapu
# Processing Record 38 of Set 11 | rio grande
# Processing Record 39 of Set 11 | rosamorada
# Processing Record 40 of Set 11 | san jose
# Processing Record 41 of Set 11 | santiago
# Processing Record 42 of Set 11 | sao felix do xingu
# Processing Record 43 of Set 11 | la verne
# Processing Record 44 of Set 11 | jackson
# Processing Record 45 of Set 11 | lodwar
# Processing Record 46 of Set 11 | presidente venceslau
# Processing Record 47 of Set 11 | chongoyape
# Processing Record 48 of Set 11 | idlib
# Processing Record 49 of Set 11 | syracuse
# Processing Record 50 of Set 11 | chunskiy
# Processing Record 1 of Set 12 | karratha
# Processing Record 2 of Set 12 | afua
# Processing Record 3 of Set 12 | peace river
# Processing Record 4 of Set 12 | chengmai
# City not found. Skipping...
# Processing Record 5 of Set 12 | isangel
# Processing Record 6 of Set 12 | finnsnes
# Processing Record 7 of Set 12 | goulburn
# Processing Record 8 of Set 12 | sterling
# Processing Record 9 of Set 12 | hohhot
# Processing Record 10 of Set 12 | hami
# Processing Record 11 of Set 12 | halalo
# City not found. Skipping...
# Processing Record 12 of Set 12 | quilmana
# Processing Record 13 of Set 12 | a
# City not found. Skipping...
# Processing Record 14 of Set 12 | benjamin constant
# Processing Record 15 of Set 12 | kourou
# Processing Record 16 of Set 12 | port arthur
# Processing Record 17 of Set 12 | batemans bay
# Processing Record 18 of Set 12 | cockburn town
# Processing Record 19 of Set 12 | guayaramerin
# Processing Record 20 of Set 12 | tikrit
# Processing Record 21 of Set 12 | guiratinga
# Processing Record 22 of Set 12 | saint-louis
# Processing Record 23 of Set 12 | gallup
# Processing Record 24 of Set 12 | pedasi
# Processing Record 25 of Set 12 | doda
# Processing Record 26 of Set 12 | sant julia de loria
# Processing Record 27 of Set 12 | keti bandar
# Processing Record 28 of Set 12 | gorgan
# Processing Record 29 of Set 12 | mujiayingzi
# Processing Record 30 of Set 12 | burns lake
# Processing Record 31 of Set 12 | petrovskaya
# Processing Record 32 of Set 12 | elizabeth city
# Processing Record 33 of Set 12 | ust-tsilma
# Processing Record 34 of Set 12 | kaeo
# Processing Record 35 of Set 12 | inuvik
# Processing Record 36 of Set 12 | bilibino
# Processing Record 37 of Set 12 | tabasalu
# Processing Record 38 of Set 12 | katete
# Processing Record 39 of Set 12 | arya
# Processing Record 40 of Set 12 | seguin
# Processing Record 41 of Set 12 | rafaela
# Processing Record 42 of Set 12 | ondorhaan
# City not found. Skipping...
# Processing Record 43 of Set 12 | provost
# Processing Record 44 of Set 12 | daru
# Processing Record 45 of Set 12 | erzincan
# Processing Record 46 of Set 12 | quchan
# Processing Record 47 of Set 12 | langub
# Processing Record 48 of Set 12 | akureyri
# Processing Record 49 of Set 12 | lincoln
# Processing Record 50 of Set 12 | san carlos de bariloche
# Processing Record 1 of Set 13 | mayor pablo lagerenza
# Processing Record 2 of Set 13 | kyren
# Processing Record 3 of Set 13 | gamba
# Processing Record 4 of Set 13 | carmo do rio claro
# Processing Record 5 of Set 13 | forssa
# Processing Record 6 of Set 13 | komsomolskiy
# Processing Record 7 of Set 13 | arinos
# Processing Record 8 of Set 13 | quatre cocos
# Processing Record 9 of Set 13 | souris
# Processing Record 10 of Set 13 | boguchany
# Processing Record 11 of Set 13 | lillooet
# Processing Record 12 of Set 13 | hambantota
# Processing Record 13 of Set 13 | murgab
# Processing Record 14 of Set 13 | tasbuget
# City not found. Skipping...
# Processing Record 15 of Set 13 | starovelichkovskaya
# Processing Record 16 of Set 13 | juneau
# Processing Record 17 of Set 13 | shemonaikha
# Processing Record 18 of Set 13 | manitouwadge
# Processing Record 19 of Set 13 | saurimo
# Processing Record 20 of Set 13 | pacifica
# Processing Record 21 of Set 13 | kathmandu
# Processing Record 22 of Set 13 | atar
# Processing Record 23 of Set 13 | pryozerne
# Processing Record 24 of Set 13 | richards bay
# Processing Record 25 of Set 13 | hirara
# Processing Record 26 of Set 13 | luwuk
# Processing Record 27 of Set 13 | kirakira
# Processing Record 28 of Set 13 | utiel
# Processing Record 29 of Set 13 | sovetskiy
# Processing Record 30 of Set 13 | dali
# Processing Record 31 of Set 13 | wajir
# Processing Record 32 of Set 13 | cordoba
# Processing Record 33 of Set 13 | guerrero negro
# Processing Record 34 of Set 13 | arvika
# Processing Record 35 of Set 13 | tukums
# Processing Record 36 of Set 13 | dharan
# Processing Record 37 of Set 13 | lithakia
# Processing Record 38 of Set 13 | turtkul
# City not found. Skipping...
# Processing Record 39 of Set 13 | mormugao
# Processing Record 40 of Set 13 | tonj
# Processing Record 41 of Set 13 | partyzany
# Processing Record 42 of Set 13 | kupang
# Processing Record 43 of Set 13 | sakaiminato
# Processing Record 44 of Set 13 | pinega
# Processing Record 45 of Set 13 | zhicheng
# Processing Record 46 of Set 13 | santa ines
# Processing Record 47 of Set 13 | aksarka
# Processing Record 48 of Set 13 | utiroa
# City not found. Skipping...
# Processing Record 49 of Set 13 | omboue
# Processing Record 50 of Set 13 | neuquen
# Processing Record 1 of Set 14 | cesenatico
# Processing Record 2 of Set 14 | omsukchan
# Processing Record 3 of Set 14 | saint cloud
# Processing Record 4 of Set 14 | tygda
# Processing Record 5 of Set 14 | boyolangu
# Processing Record 6 of Set 14 | bulgan
# Processing Record 7 of Set 14 | alanya
# Processing Record 8 of Set 14 | savelugu
# Processing Record 9 of Set 14 | toliary
# City not found. Skipping...
# Processing Record 10 of Set 14 | ukiah
# Processing Record 11 of Set 14 | plettenberg bay
# Processing Record 12 of Set 14 | huallanca
# Processing Record 13 of Set 14 | kamenka
# Processing Record 14 of Set 14 | bonavista
# Processing Record 15 of Set 14 | bebedouro
# Processing Record 16 of Set 14 | alofi
# Processing Record 17 of Set 14 | asyut
# Processing Record 18 of Set 14 | fonte boa
# Processing Record 19 of Set 14 | kotelnich
# Processing Record 20 of Set 14 | baghdad
# Processing Record 21 of Set 14 | dongsheng
# Processing Record 22 of Set 14 | teahupoo
# Processing Record 23 of Set 14 | manicore
# Processing Record 24 of Set 14 | nevsehir
# Processing Record 25 of Set 14 | carballo
# Processing Record 26 of Set 14 | saint pete beach
# Processing Record 27 of Set 14 | magadan
# Processing Record 28 of Set 14 | gizo
# Processing Record 29 of Set 14 | vao
# Processing Record 30 of Set 14 | tupaciguara
# Processing Record 31 of Set 14 | ust-kuyga
# Processing Record 32 of Set 14 | barra do garcas
# Processing Record 33 of Set 14 | ulaangom
# Processing Record 34 of Set 14 | qandahar
# City not found. Skipping...
# Processing Record 35 of Set 14 | talnakh
# Processing Record 36 of Set 14 | teknaf
# Processing Record 37 of Set 14 | yakovlevka
# Processing Record 38 of Set 14 | hammerfest
# Processing Record 39 of Set 14 | yining
# Processing Record 40 of Set 14 | ketchikan
# Processing Record 41 of Set 14 | irbit
# Processing Record 42 of Set 14 | calvinia
# Processing Record 43 of Set 14 | ikungi
# Processing Record 44 of Set 14 | mackay
# Processing Record 45 of Set 14 | bhola
# Processing Record 46 of Set 14 | ruwi
# Processing Record 47 of Set 14 | ust-maya
# Processing Record 48 of Set 14 | poum
# Processing Record 49 of Set 14 | stonewall
# Processing Record 50 of Set 14 | kisangani
# Processing Record 1 of Set 15 | corbelia
# Processing Record 2 of Set 15 | oussouye
# Processing Record 3 of Set 15 | drahovo
# Processing Record 4 of Set 15 | itarema
# Processing Record 5 of Set 15 | tairua
# Processing Record 6 of Set 15 | ozernovskiy
# Processing Record 7 of Set 15 | sarh
# Processing Record 8 of Set 15 | batsfjord
# Processing Record 9 of Set 15 | wageningen
# Processing Record 10 of Set 15 | moba
# Processing Record 11 of Set 15 | yumen
# Processing Record 12 of Set 15 | sakakah
# Processing Record 13 of Set 15 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 14 of Set 15 | pizarro
# Processing Record 15 of Set 15 | miri
# Processing Record 16 of Set 15 | ust-omchug
# Processing Record 17 of Set 15 | usinsk
# Processing Record 18 of Set 15 | gallatin
# Processing Record 19 of Set 15 | broken hill
# Processing Record 20 of Set 15 | piacabucu
# Processing Record 21 of Set 15 | angoche
# Processing Record 22 of Set 15 | goundam
# Processing Record 23 of Set 15 | tuatapere
# Processing Record 24 of Set 15 | san quintin
# Processing Record 25 of Set 15 | margate
# Processing Record 26 of Set 15 | kem
# Processing Record 27 of Set 15 | waldshut-tiengen
# Processing Record 28 of Set 15 | marsh harbour
# Processing Record 29 of Set 15 | okitipupa
# Processing Record 30 of Set 15 | kuche
# City not found. Skipping...
# Processing Record 31 of Set 15 | kungurtug
# Processing Record 32 of Set 15 | sambava
# Processing Record 33 of Set 15 | trelew
# Processing Record 34 of Set 15 | krasnyy chikoy
# Processing Record 35 of Set 15 | viligili
# City not found. Skipping...
# Processing Record 36 of Set 15 | winton
# Processing Record 37 of Set 15 | kapenguria
# Processing Record 38 of Set 15 | awbari
# Processing Record 39 of Set 15 | brae
# Processing Record 40 of Set 15 | pucallpa
# Processing Record 41 of Set 15 | pokosnoye
# Processing Record 42 of Set 15 | whitehorse
# Processing Record 43 of Set 15 | cap malheureux
# Processing Record 44 of Set 15 | dourbali
# Processing Record 45 of Set 15 | kenai
# Processing Record 46 of Set 15 | shitanjing
# Processing Record 47 of Set 15 | umm bab
# Processing Record 48 of Set 15 | dolbeau
# City not found. Skipping...
# Processing Record 49 of Set 15 | balikpapan
# Processing Record 50 of Set 15 | naberera
# Processing Record 1 of Set 16 | caramay
# Processing Record 2 of Set 16 | oranjestad
# Processing Record 3 of Set 16 | setermoen
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 694

# %% [markdown]
# ### Add the data to a new DataFrame

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Hasaki      JP  35.7333  140.8333     46.00        49          20
# 1       Melendugno      IT  40.2747   18.3368     57.00        93           0
# 2            Vardo      NO  70.3705   31.1107     33.80        69          20
# 3     Ponta Do Sol      PT  32.6667  -17.1000     59.00        86          54
# 4  Arraial Do Cabo      BR -22.9661  -42.0278     77.00        88           0
# 5           Matara      LK   5.9485   80.5353     77.25        88          21
# 6           Atuona      PF  -9.8000 -139.0333     79.86        73          47
# 7     Kuala Lumpur      MY   3.1431  101.6865     78.80        89          20
# 8            Kapaa      US  22.0752 -159.3190     80.60        61          40
# 9             Lebu      CL -37.6167  -73.6500     58.50        81           0
#
#    Wind Speed Current Description
# 0       13.80          few clouds
# 1        2.30           clear sky
# 2       13.80          few clouds
# 3        5.01       broken clouds
# 4        6.91           clear sky
# 5        2.89          few clouds
# 6       14.85    scattered clouds
# 7        2.19          few clouds
# 8       16.11    scattered clouds
# 9       11.86           clear sky

# %% [markdown]
# ### Export the DataFrame as a CSV file

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"

# Export the WeatherPy_Database into a CSV.
weatherPy_database_df.to_csv(output_data_file, index_label="City_ID")
