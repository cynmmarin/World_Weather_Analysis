# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Create a new set of 2,000 random latitudes and longitudes

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %% [markdown]
# ### Get the nearest city using the citipy module

# %%
from citipy import citipy

# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

        # Print the city count to confirm sufficient count.
len(cities)
# Out:
# 759

# %% [markdown]
# ### Perform an API call with the OpenWeatherMap

# %%
# Import the requests library.
import requests

## Import the datetime module from the datetime library.
from datetime import datetime

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d3fe34a1634f05652b89a64616ae194

# %% [markdown]
# ### Retrieve the following information from the API call

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

 # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather['weather'][0]['description']
    
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
       
    # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | jamestown
# Processing Record 2 of Set 1 | lashio
# Processing Record 3 of Set 1 | vardo
# Processing Record 4 of Set 1 | tara
# Processing Record 5 of Set 1 | arraial do cabo
# Processing Record 6 of Set 1 | castro
# Processing Record 7 of Set 1 | aksarka
# Processing Record 8 of Set 1 | punta arenas
# Processing Record 9 of Set 1 | ushuaia
# Processing Record 10 of Set 1 | iskateley
# Processing Record 11 of Set 1 | nikolskoye
# Processing Record 12 of Set 1 | albany
# Processing Record 13 of Set 1 | beringovskiy
# Processing Record 14 of Set 1 | puerto ayora
# Processing Record 15 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 16 of Set 1 | rikitea
# Processing Record 17 of Set 1 | kutum
# Processing Record 18 of Set 1 | busselton
# Processing Record 19 of Set 1 | itarema
# Processing Record 20 of Set 1 | bluff
# Processing Record 21 of Set 1 | carnarvon
# Processing Record 22 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 23 of Set 1 | hermanus
# Processing Record 24 of Set 1 | mataura
# Processing Record 25 of Set 1 | saint-philippe
# Processing Record 26 of Set 1 | georgetown
# Processing Record 27 of Set 1 | olafsvik
# Processing Record 28 of Set 1 | upernavik
# Processing Record 29 of Set 1 | alta floresta
# Processing Record 30 of Set 1 | saint george
# Processing Record 31 of Set 1 | naze
# Processing Record 32 of Set 1 | severo-kurilsk
# Processing Record 33 of Set 1 | san policarpo
# Processing Record 34 of Set 1 | hilo
# Processing Record 35 of Set 1 | taoudenni
# Processing Record 36 of Set 1 | nerchinskiy zavod
# Processing Record 37 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 38 of Set 1 | tuscaloosa
# Processing Record 39 of Set 1 | avarua
# Processing Record 40 of Set 1 | cubulco
# Processing Record 41 of Set 1 | dinguiraye
# Processing Record 42 of Set 1 | boende
# Processing Record 43 of Set 1 | leningradskiy
# Processing Record 44 of Set 1 | cherskiy
# Processing Record 45 of Set 1 | port elizabeth
# Processing Record 46 of Set 1 | hambantota
# Processing Record 47 of Set 1 | nambucca heads
# Processing Record 48 of Set 1 | hobart
# Processing Record 49 of Set 1 | bambous virieux
# Processing Record 50 of Set 1 | viedma
# Processing Record 1 of Set 2 | provideniya
# Processing Record 2 of Set 2 | kenai
# Processing Record 3 of Set 2 | vila franca do campo
# Processing Record 4 of Set 2 | kodiak
# Processing Record 5 of Set 2 | strezhevoy
# Processing Record 6 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 7 of Set 2 | kota belud
# Processing Record 8 of Set 2 | pitanga
# Processing Record 9 of Set 2 | asau
# Processing Record 10 of Set 2 | richards bay
# Processing Record 11 of Set 2 | sao joao da barra
# Processing Record 12 of Set 2 | chimbote
# Processing Record 13 of Set 2 | konosha
# Processing Record 14 of Set 2 | aleksandrov gay
# Processing Record 15 of Set 2 | yokadouma
# Processing Record 16 of Set 2 | atuona
# Processing Record 17 of Set 2 | ardesen
# Processing Record 18 of Set 2 | kruisfontein
# Processing Record 19 of Set 2 | aquiraz
# Processing Record 20 of Set 2 | vaini
# Processing Record 21 of Set 2 | rawannawi
# City not found. Skipping...
# Processing Record 22 of Set 2 | bethel
# Processing Record 23 of Set 2 | butaritari
# Processing Record 24 of Set 2 | bredasdorp
# Processing Record 25 of Set 2 | klaksvik
# Processing Record 26 of Set 2 | toamasina
# Processing Record 27 of Set 2 | yuci
# Processing Record 28 of Set 2 | kapaa
# Processing Record 29 of Set 2 | nemuro
# Processing Record 30 of Set 2 | kamenka
# Processing Record 31 of Set 2 | tiksi
# Processing Record 32 of Set 2 | ancud
# Processing Record 33 of Set 2 | gurgan
# City not found. Skipping...
# Processing Record 34 of Set 2 | mar del plata
# Processing Record 35 of Set 2 | price
# Processing Record 36 of Set 2 | robinson
# Processing Record 37 of Set 2 | mizan teferi
# Processing Record 38 of Set 2 | east millcreek
# Processing Record 39 of Set 2 | djambala
# Processing Record 40 of Set 2 | samalaeulu
# City not found. Skipping...
# Processing Record 41 of Set 2 | karratha
# Processing Record 42 of Set 2 | mogadishu
# Processing Record 43 of Set 2 | cidreira
# Processing Record 44 of Set 2 | pavilosta
# Processing Record 45 of Set 2 | springdale
# Processing Record 46 of Set 2 | nouadhibou
# Processing Record 47 of Set 2 | loreto
# Processing Record 48 of Set 2 | pevek
# Processing Record 49 of Set 2 | mount gambier
# Processing Record 50 of Set 2 | haibowan
# City not found. Skipping...
# Processing Record 1 of Set 3 | lebanon
# Processing Record 2 of Set 3 | lebu
# Processing Record 3 of Set 3 | seoul
# Processing Record 4 of Set 3 | hasaki
# Processing Record 5 of Set 3 | cape town
# Processing Record 6 of Set 3 | onverwacht
# Processing Record 7 of Set 3 | prince rupert
# Processing Record 8 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 9 of Set 3 | sombrio
# Processing Record 10 of Set 3 | somerset east
# Processing Record 11 of Set 3 | boyolangu
# Processing Record 12 of Set 3 | sitka
# Processing Record 13 of Set 3 | leshukonskoye
# Processing Record 14 of Set 3 | yumen
# Processing Record 15 of Set 3 | mahebourg
# Processing Record 16 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 17 of Set 3 | samarai
# Processing Record 18 of Set 3 | cedar rapids
# Processing Record 19 of Set 3 | souillac
# Processing Record 20 of Set 3 | kununurra
# Processing Record 21 of Set 3 | chicama
# Processing Record 22 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 23 of Set 3 | vila velha
# Processing Record 24 of Set 3 | new norfolk
# Processing Record 25 of Set 3 | hualmay
# Processing Record 26 of Set 3 | rawson
# Processing Record 27 of Set 3 | east london
# Processing Record 28 of Set 3 | karamea
# City not found. Skipping...
# Processing Record 29 of Set 3 | dolores
# Processing Record 30 of Set 3 | nador
# Processing Record 31 of Set 3 | sorland
# Processing Record 32 of Set 3 | comodoro rivadavia
# Processing Record 33 of Set 3 | moose factory
# Processing Record 34 of Set 3 | cervo
# Processing Record 35 of Set 3 | ballina
# Processing Record 36 of Set 3 | gravdal
# Processing Record 37 of Set 3 | padang
# Processing Record 38 of Set 3 | ahipara
# Processing Record 39 of Set 3 | mayo
# Processing Record 40 of Set 3 | murdochville
# Processing Record 41 of Set 3 | glyadyanskoye
# Processing Record 42 of Set 3 | dikson
# Processing Record 43 of Set 3 | hervey bay
# Processing Record 44 of Set 3 | airai
# Processing Record 45 of Set 3 | iwanai
# Processing Record 46 of Set 3 | abu kamal
# Processing Record 47 of Set 3 | acarau
# Processing Record 48 of Set 3 | mackay
# Processing Record 49 of Set 3 | norman wells
# Processing Record 50 of Set 3 | port alfred
# Processing Record 1 of Set 4 | sinnamary
# Processing Record 2 of Set 4 | paralimni
# Processing Record 3 of Set 4 | havoysund
# Processing Record 4 of Set 4 | tasiilaq
# Processing Record 5 of Set 4 | teguise
# Processing Record 6 of Set 4 | ribeira grande
# Processing Record 7 of Set 4 | kalmunai
# Processing Record 8 of Set 4 | brownsville
# Processing Record 9 of Set 4 | marawi
# Processing Record 10 of Set 4 | victoria
# Processing Record 11 of Set 4 | pangnirtung
# Processing Record 12 of Set 4 | barrow
# Processing Record 13 of Set 4 | san luis
# Processing Record 14 of Set 4 | yulara
# Processing Record 15 of Set 4 | chekhov
# Processing Record 16 of Set 4 | bajo baudo
# City not found. Skipping...
# Processing Record 17 of Set 4 | kaohsiung
# Processing Record 18 of Set 4 | skibbereen
# Processing Record 19 of Set 4 | cieza
# Processing Record 20 of Set 4 | goure
# Processing Record 21 of Set 4 | malko tarnovo
# Processing Record 22 of Set 4 | codrington
# Processing Record 23 of Set 4 | vuktyl
# Processing Record 24 of Set 4 | muborak
# Processing Record 25 of Set 4 | rabat
# Processing Record 26 of Set 4 | thompson
# Processing Record 27 of Set 4 | thaba-tseka
# Processing Record 28 of Set 4 | sainte-marie
# Processing Record 29 of Set 4 | sovetskaya gavan
# Processing Record 30 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 31 of Set 4 | goderich
# Processing Record 32 of Set 4 | belen
# Processing Record 33 of Set 4 | kavaratti
# Processing Record 34 of Set 4 | enkoping
# Processing Record 35 of Set 4 | galesong
# Processing Record 36 of Set 4 | college
# Processing Record 37 of Set 4 | orocovis
# Processing Record 38 of Set 4 | stromness
# Processing Record 39 of Set 4 | saldanha
# Processing Record 40 of Set 4 | navegantes
# Processing Record 41 of Set 4 | okha
# Processing Record 42 of Set 4 | namibe
# Processing Record 43 of Set 4 | lompoc
# Processing Record 44 of Set 4 | lev tolstoy
# Processing Record 45 of Set 4 | bengkulu
# Processing Record 46 of Set 4 | lavrentiya
# Processing Record 47 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 48 of Set 4 | chegdomyn
# Processing Record 49 of Set 4 | hof
# Processing Record 50 of Set 4 | luwuk
# Processing Record 1 of Set 5 | quimper
# Processing Record 2 of Set 5 | arlit
# Processing Record 3 of Set 5 | vestmanna
# Processing Record 4 of Set 5 | longyearbyen
# Processing Record 5 of Set 5 | bathsheba
# Processing Record 6 of Set 5 | katsuura
# Processing Record 7 of Set 5 | hamilton
# Processing Record 8 of Set 5 | kahului
# Processing Record 9 of Set 5 | the valley
# Processing Record 10 of Set 5 | batsfjord
# Processing Record 11 of Set 5 | port lincoln
# Processing Record 12 of Set 5 | bealanana
# Processing Record 13 of Set 5 | san patricio
# Processing Record 14 of Set 5 | tonekabon
# Processing Record 15 of Set 5 | serenje
# Processing Record 16 of Set 5 | batemans bay
# Processing Record 17 of Set 5 | eyl
# Processing Record 18 of Set 5 | lamu
# Processing Record 19 of Set 5 | alofi
# Processing Record 20 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 21 of Set 5 | cabo san lucas
# Processing Record 22 of Set 5 | penzance
# Processing Record 23 of Set 5 | kifri
# Processing Record 24 of Set 5 | qaanaaq
# Processing Record 25 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 26 of Set 5 | hithadhoo
# Processing Record 27 of Set 5 | santa marta
# Processing Record 28 of Set 5 | naples
# Processing Record 29 of Set 5 | manggar
# Processing Record 30 of Set 5 | grande prairie
# Processing Record 31 of Set 5 | tuktoyaktuk
# Processing Record 32 of Set 5 | faanui
# Processing Record 33 of Set 5 | pandan
# Processing Record 34 of Set 5 | inderborskiy
# City not found. Skipping...
# Processing Record 35 of Set 5 | contamana
# Processing Record 36 of Set 5 | kattivakkam
# Processing Record 37 of Set 5 | hassleholm
# Processing Record 38 of Set 5 | acapulco
# Processing Record 39 of Set 5 | alekseyevsk
# Processing Record 40 of Set 5 | pagudpud
# Processing Record 41 of Set 5 | tahta
# Processing Record 42 of Set 5 | hofn
# Processing Record 43 of Set 5 | urucui
# Processing Record 44 of Set 5 | zaqatala
# Processing Record 45 of Set 5 | arman
# Processing Record 46 of Set 5 | arrecife
# Processing Record 47 of Set 5 | coahuayana
# Processing Record 48 of Set 5 | wagga wagga
# Processing Record 49 of Set 5 | mount isa
# Processing Record 50 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 1 of Set 6 | joshimath
# Processing Record 2 of Set 6 | hobyo
# Processing Record 3 of Set 6 | noumea
# Processing Record 4 of Set 6 | kathu
# Processing Record 5 of Set 6 | taltal
# Processing Record 6 of Set 6 | celestun
# Processing Record 7 of Set 6 | villazon
# Processing Record 8 of Set 6 | pinawa
# Processing Record 9 of Set 6 | nanortalik
# Processing Record 10 of Set 6 | meulaboh
# Processing Record 11 of Set 6 | kikwit
# Processing Record 12 of Set 6 | mokhsogollokh
# Processing Record 13 of Set 6 | chuy
# Processing Record 14 of Set 6 | chepareria
# Processing Record 15 of Set 6 | eirunepe
# Processing Record 16 of Set 6 | warrington
# Processing Record 17 of Set 6 | neman
# Processing Record 18 of Set 6 | ponta do sol
# Processing Record 19 of Set 6 | mascota
# Processing Record 20 of Set 6 | campos novos
# Processing Record 21 of Set 6 | pogar
# Processing Record 22 of Set 6 | yellowknife
# Processing Record 23 of Set 6 | capela
# Processing Record 24 of Set 6 | cockburn town
# Processing Record 25 of Set 6 | eregli
# Processing Record 26 of Set 6 | ostrovnoy
# Processing Record 27 of Set 6 | esperance
# Processing Record 28 of Set 6 | saint-augustin
# Processing Record 29 of Set 6 | mbanza-ngungu
# Processing Record 30 of Set 6 | natalinsk
# Processing Record 31 of Set 6 | tuy hoa
# Processing Record 32 of Set 6 | caravelas
# Processing Record 33 of Set 6 | nabire
# Processing Record 34 of Set 6 | kontagora
# Processing Record 35 of Set 6 | kaitangata
# Processing Record 36 of Set 6 | grindavik
# Processing Record 37 of Set 6 | manzanillo
# Processing Record 38 of Set 6 | chokurdakh
# Processing Record 39 of Set 6 | itoman
# Processing Record 40 of Set 6 | pacific grove
# Processing Record 41 of Set 6 | pafos
# Processing Record 42 of Set 6 | takaka
# Processing Record 43 of Set 6 | itaituba
# Processing Record 44 of Set 6 | jardim
# Processing Record 45 of Set 6 | oda
# Processing Record 46 of Set 6 | erzin
# Processing Record 47 of Set 6 | sao filipe
# Processing Record 48 of Set 6 | didi lilo
# Processing Record 49 of Set 6 | kulu
# Processing Record 50 of Set 6 | sibi
# Processing Record 1 of Set 7 | dongsheng
# Processing Record 2 of Set 7 | luderitz
# Processing Record 3 of Set 7 | kuche
# City not found. Skipping...
# Processing Record 4 of Set 7 | mnogovershinnyy
# Processing Record 5 of Set 7 | khani
# Processing Record 6 of Set 7 | alyangula
# Processing Record 7 of Set 7 | ciras
# City not found. Skipping...
# Processing Record 8 of Set 7 | mantua
# Processing Record 9 of Set 7 | nicolas bravo
# Processing Record 10 of Set 7 | saint-pierre
# Processing Record 11 of Set 7 | morant bay
# Processing Record 12 of Set 7 | taos
# Processing Record 13 of Set 7 | dingle
# Processing Record 14 of Set 7 | alto araguaia
# Processing Record 15 of Set 7 | vertientes
# Processing Record 16 of Set 7 | ouro branco
# Processing Record 17 of Set 7 | fortuna
# Processing Record 18 of Set 7 | toora-khem
# Processing Record 19 of Set 7 | khatanga
# Processing Record 20 of Set 7 | kapit
# Processing Record 21 of Set 7 | hendek
# Processing Record 22 of Set 7 | japura
# Processing Record 23 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 24 of Set 7 | ovruch
# Processing Record 25 of Set 7 | vestmannaeyjar
# Processing Record 26 of Set 7 | cabinda
# Processing Record 27 of Set 7 | touros
# Processing Record 28 of Set 7 | gamba
# Processing Record 29 of Set 7 | ranong
# Processing Record 30 of Set 7 | eskasem
# City not found. Skipping...
# Processing Record 31 of Set 7 | safranbolu
# Processing Record 32 of Set 7 | tchibanga
# Processing Record 33 of Set 7 | esil
# Processing Record 34 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 35 of Set 7 | half moon bay
# Processing Record 36 of Set 7 | grand gaube
# Processing Record 37 of Set 7 | ludesti
# Processing Record 38 of Set 7 | saint-prosper
# Processing Record 39 of Set 7 | bagdarin
# Processing Record 40 of Set 7 | muisne
# Processing Record 41 of Set 7 | emmanouil pappas
# Processing Record 42 of Set 7 | stolberg
# Processing Record 43 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 44 of Set 7 | libreville
# Processing Record 45 of Set 7 | barbar
# City not found. Skipping...
# Processing Record 46 of Set 7 | muli
# Processing Record 47 of Set 7 | wuwei
# Processing Record 48 of Set 7 | labuhan
# Processing Record 49 of Set 7 | lagoa
# Processing Record 50 of Set 7 | jamame
# Processing Record 1 of Set 8 | saskylakh
# Processing Record 2 of Set 8 | talnakh
# Processing Record 3 of Set 8 | yarim
# Processing Record 4 of Set 8 | koungou
# Processing Record 5 of Set 8 | yeniseysk
# Processing Record 6 of Set 8 | banmo
# City not found. Skipping...
# Processing Record 7 of Set 8 | salalah
# Processing Record 8 of Set 8 | pitimbu
# Processing Record 9 of Set 8 | constitucion
# Processing Record 10 of Set 8 | portland
# Processing Record 11 of Set 8 | borshchiv
# Processing Record 12 of Set 8 | sterling
# Processing Record 13 of Set 8 | langsa
# Processing Record 14 of Set 8 | talaya
# Processing Record 15 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 16 of Set 8 | dondo
# Processing Record 17 of Set 8 | sabya
# Processing Record 18 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 19 of Set 8 | rio gallegos
# Processing Record 20 of Set 8 | tiarei
# Processing Record 21 of Set 8 | ukiah
# Processing Record 22 of Set 8 | hayden
# Processing Record 23 of Set 8 | ridgecrest
# Processing Record 24 of Set 8 | tidore
# City not found. Skipping...
# Processing Record 25 of Set 8 | martapura
# Processing Record 26 of Set 8 | port macquarie
# Processing Record 27 of Set 8 | torbay
# Processing Record 28 of Set 8 | solotcha
# Processing Record 29 of Set 8 | saint anthony
# Processing Record 30 of Set 8 | inuvik
# Processing Record 31 of Set 8 | lata
# Processing Record 32 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 33 of Set 8 | raudeberg
# Processing Record 34 of Set 8 | zhanaozen
# Processing Record 35 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 36 of Set 8 | kavieng
# Processing Record 37 of Set 8 | santa rosa
# Processing Record 38 of Set 8 | carlos chagas
# Processing Record 39 of Set 8 | valdosta
# Processing Record 40 of Set 8 | semey
# Processing Record 41 of Set 8 | akyab
# Processing Record 42 of Set 8 | honggang
# Processing Record 43 of Set 8 | muros
# Processing Record 44 of Set 8 | dwarka
# Processing Record 45 of Set 8 | kropotkin
# Processing Record 46 of Set 8 | salinopolis
# Processing Record 47 of Set 8 | scarborough
# Processing Record 48 of Set 8 | urumqi
# Processing Record 49 of Set 8 | alcantara
# Processing Record 50 of Set 8 | valdivia
# Processing Record 1 of Set 9 | malanje
# Processing Record 2 of Set 9 | matara
# Processing Record 3 of Set 9 | itaberaba
# Processing Record 4 of Set 9 | vanimo
# Processing Record 5 of Set 9 | kendari
# Processing Record 6 of Set 9 | ambilobe
# Processing Record 7 of Set 9 | flinders
# Processing Record 8 of Set 9 | maningrida
# Processing Record 9 of Set 9 | shimoda
# Processing Record 10 of Set 9 | namatanai
# Processing Record 11 of Set 9 | moratuwa
# Processing Record 12 of Set 9 | aksha
# Processing Record 13 of Set 9 | tomatlan
# Processing Record 14 of Set 9 | tunceli
# Processing Record 15 of Set 9 | coquimbo
# Processing Record 16 of Set 9 | sola
# Processing Record 17 of Set 9 | satitoa
# City not found. Skipping...
# Processing Record 18 of Set 9 | portales
# Processing Record 19 of Set 9 | eufaula
# Processing Record 20 of Set 9 | san bartolome
# Processing Record 21 of Set 9 | sisophon
# Processing Record 22 of Set 9 | vidim
# Processing Record 23 of Set 9 | ilulissat
# Processing Record 24 of Set 9 | kirakira
# Processing Record 25 of Set 9 | skalistyy
# City not found. Skipping...
# Processing Record 26 of Set 9 | tucurui
# Processing Record 27 of Set 9 | zabol
# Processing Record 28 of Set 9 | marabba
# Processing Record 29 of Set 9 | marmora
# Processing Record 30 of Set 9 | hoquiam
# Processing Record 31 of Set 9 | los llanos de aridane
# Processing Record 32 of Set 9 | oriximina
# Processing Record 33 of Set 9 | cayenne
# Processing Record 34 of Set 9 | seminole
# Processing Record 35 of Set 9 | torres
# Processing Record 36 of Set 9 | bima
# Processing Record 37 of Set 9 | havre-saint-pierre
# Processing Record 38 of Set 9 | syracuse
# Processing Record 39 of Set 9 | bajil
# Processing Record 40 of Set 9 | dukstas
# Processing Record 41 of Set 9 | inirida
# Processing Record 42 of Set 9 | elk city
# Processing Record 43 of Set 9 | trois-rivieres
# Processing Record 44 of Set 9 | port hardy
# Processing Record 45 of Set 9 | novoagansk
# Processing Record 46 of Set 9 | soyo
# Processing Record 47 of Set 9 | bilibino
# Processing Record 48 of Set 9 | haysville
# Processing Record 49 of Set 9 | saint-joseph
# Processing Record 50 of Set 9 | taboga
# Processing Record 1 of Set 10 | valenca
# Processing Record 2 of Set 10 | vung tau
# Processing Record 3 of Set 10 | westport
# Processing Record 4 of Set 10 | farmington
# Processing Record 5 of Set 10 | ussuriysk
# Processing Record 6 of Set 10 | raisinghnagar
# Processing Record 7 of Set 10 | jiangyou
# Processing Record 8 of Set 10 | ngukurr
# City not found. Skipping...
# Processing Record 9 of Set 10 | dhangadhi
# Processing Record 10 of Set 10 | dafeng
# Processing Record 11 of Set 10 | bethanien
# Processing Record 12 of Set 10 | tuatapere
# Processing Record 13 of Set 10 | neryungri
# Processing Record 14 of Set 10 | ulaangom
# Processing Record 15 of Set 10 | geraldton
# Processing Record 16 of Set 10 | brae
# Processing Record 17 of Set 10 | semenivka
# Processing Record 18 of Set 10 | mecca
# Processing Record 19 of Set 10 | kasra
# City not found. Skipping...
# Processing Record 20 of Set 10 | omboue
# Processing Record 21 of Set 10 | maumere
# Processing Record 22 of Set 10 | inta
# Processing Record 23 of Set 10 | sakete
# Processing Record 24 of Set 10 | serebryansk
# Processing Record 25 of Set 10 | kilrush
# Processing Record 26 of Set 10 | olhao
# Processing Record 27 of Set 10 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 28 of Set 10 | melita
# Processing Record 29 of Set 10 | zadar
# Processing Record 30 of Set 10 | nanga eboko
# Processing Record 31 of Set 10 | guhagar
# Processing Record 32 of Set 10 | iqaluit
# Processing Record 33 of Set 10 | khazar
# Processing Record 34 of Set 10 | narsaq
# Processing Record 35 of Set 10 | gisborne
# Processing Record 36 of Set 10 | road town
# Processing Record 37 of Set 10 | yirol
# City not found. Skipping...
# Processing Record 38 of Set 10 | laranjeiras do sul
# Processing Record 39 of Set 10 | kurilsk
# Processing Record 40 of Set 10 | haines junction
# Processing Record 41 of Set 10 | koumac
# Processing Record 42 of Set 10 | arica
# Processing Record 43 of Set 10 | hornepayne
# Processing Record 44 of Set 10 | tual
# Processing Record 45 of Set 10 | faya
# Processing Record 46 of Set 10 | januaria
# Processing Record 47 of Set 10 | potgietersrus
# City not found. Skipping...
# Processing Record 48 of Set 10 | evensk
# Processing Record 49 of Set 10 | umm jarr
# City not found. Skipping...
# Processing Record 50 of Set 10 | athabasca
# Processing Record 1 of Set 11 | aflu
# City not found. Skipping...
# Processing Record 2 of Set 11 | verkhnyaya inta
# Processing Record 3 of Set 11 | hay river
# Processing Record 4 of Set 11 | sinazongwe
# Processing Record 5 of Set 11 | yushan
# Processing Record 6 of Set 11 | nome
# Processing Record 7 of Set 11 | ambon
# Processing Record 8 of Set 11 | guerrero negro
# Processing Record 9 of Set 11 | broome
# Processing Record 10 of Set 11 | tecoanapa
# Processing Record 11 of Set 11 | caribou
# Processing Record 12 of Set 11 | bulawayo
# Processing Record 13 of Set 11 | khash
# Processing Record 14 of Set 11 | gat
# Processing Record 15 of Set 11 | umm lajj
# Processing Record 16 of Set 11 | pobe
# Processing Record 17 of Set 11 | mondlo
# Processing Record 18 of Set 11 | cahors
# Processing Record 19 of Set 11 | rocha
# Processing Record 20 of Set 11 | labytnangi
# Processing Record 21 of Set 11 | makakilo city
# Processing Record 22 of Set 11 | coihaique
# Processing Record 23 of Set 11 | maniitsoq
# Processing Record 24 of Set 11 | warren
# Processing Record 25 of Set 11 | manono
# Processing Record 26 of Set 11 | kalanguy
# Processing Record 27 of Set 11 | aklavik
# Processing Record 28 of Set 11 | praia
# Processing Record 29 of Set 11 | bardiyah
# Processing Record 30 of Set 11 | beaverlodge
# Processing Record 31 of Set 11 | el balyana
# City not found. Skipping...
# Processing Record 32 of Set 11 | hazelwood
# Processing Record 33 of Set 11 | valparaiso
# Processing Record 34 of Set 11 | tessalit
# Processing Record 35 of Set 11 | mangrol
# Processing Record 36 of Set 11 | clyde river
# Processing Record 37 of Set 11 | merauke
# Processing Record 38 of Set 11 | omsukchan
# Processing Record 39 of Set 11 | nizwa
# Processing Record 40 of Set 11 | mendeleyevo
# Processing Record 41 of Set 11 | ulladulla
# Processing Record 42 of Set 11 | deputatskiy
# Processing Record 43 of Set 11 | pisco
# Processing Record 44 of Set 11 | phalombe
# Processing Record 45 of Set 11 | san ramon de la nueva oran
# Processing Record 46 of Set 11 | port blair
# Processing Record 47 of Set 11 | fairbanks
# Processing Record 48 of Set 11 | barra do bugres
# Processing Record 49 of Set 11 | sataua
# City not found. Skipping...
# Processing Record 50 of Set 11 | verkhniy lomov
# Processing Record 1 of Set 12 | lanzhou
# Processing Record 2 of Set 12 | hihifo
# City not found. Skipping...
# Processing Record 3 of Set 12 | cascais
# Processing Record 4 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 5 of Set 12 | nylstroom
# City not found. Skipping...
# Processing Record 6 of Set 12 | santiago del estero
# Processing Record 7 of Set 12 | hackettstown
# Processing Record 8 of Set 12 | alice springs
# Processing Record 9 of Set 12 | oranjemund
# Processing Record 10 of Set 12 | kodinsk
# Processing Record 11 of Set 12 | lukovetskiy
# Processing Record 12 of Set 12 | betsiamites
# Processing Record 13 of Set 12 | petlawad
# Processing Record 14 of Set 12 | montrose
# Processing Record 15 of Set 12 | paita
# Processing Record 16 of Set 12 | solnechnyy
# Processing Record 17 of Set 12 | hami
# Processing Record 18 of Set 12 | yenagoa
# Processing Record 19 of Set 12 | kloulklubed
# Processing Record 20 of Set 12 | monte alegre
# Processing Record 21 of Set 12 | lincoln
# Processing Record 22 of Set 12 | westerland
# Processing Record 23 of Set 12 | nara
# Processing Record 24 of Set 12 | pauini
# Processing Record 25 of Set 12 | sept-iles
# Processing Record 26 of Set 12 | kaeo
# Processing Record 27 of Set 12 | zeya
# Processing Record 28 of Set 12 | bereda
# Processing Record 29 of Set 12 | khudumelapye
# Processing Record 30 of Set 12 | morro bay
# Processing Record 31 of Set 12 | mbigou
# Processing Record 32 of Set 12 | atambua
# Processing Record 33 of Set 12 | garoua
# Processing Record 34 of Set 12 | youghal
# Processing Record 35 of Set 12 | kuching
# Processing Record 36 of Set 12 | hardenberg
# Processing Record 37 of Set 12 | amazar
# Processing Record 38 of Set 12 | bousso
# Processing Record 39 of Set 12 | huilong
# Processing Record 40 of Set 12 | miyako
# Processing Record 41 of Set 12 | kashi
# Processing Record 42 of Set 12 | meadow lake
# Processing Record 43 of Set 12 | liverpool
# Processing Record 44 of Set 12 | catalao
# Processing Record 45 of Set 12 | raul soares
# Processing Record 46 of Set 12 | najran
# Processing Record 47 of Set 12 | avera
# Processing Record 48 of Set 12 | romny
# Processing Record 49 of Set 12 | vao
# Processing Record 50 of Set 12 | praya
# Processing Record 1 of Set 13 | komsomolskiy
# Processing Record 2 of Set 13 | zyryanka
# Processing Record 3 of Set 13 | yeppoon
# Processing Record 4 of Set 13 | te anau
# Processing Record 5 of Set 13 | nyurba
# Processing Record 6 of Set 13 | konevo
# Processing Record 7 of Set 13 | madang
# Processing Record 8 of Set 13 | tura
# Processing Record 9 of Set 13 | husavik
# Processing Record 10 of Set 13 | boke
# Processing Record 11 of Set 13 | saryshagan
# City not found. Skipping...
# Processing Record 12 of Set 13 | fayaoue
# Processing Record 13 of Set 13 | visby
# Processing Record 14 of Set 13 | fulitun
# City not found. Skipping...
# Processing Record 15 of Set 13 | zhigansk
# Processing Record 16 of Set 13 | marcona
# City not found. Skipping...
# Processing Record 17 of Set 13 | tarudant
# City not found. Skipping...
# Processing Record 18 of Set 13 | xai-xai
# Processing Record 19 of Set 13 | chaman
# Processing Record 20 of Set 13 | adrar
# Processing Record 21 of Set 13 | rio grande
# Processing Record 22 of Set 13 | necochea
# Processing Record 23 of Set 13 | conchas
# Processing Record 24 of Set 13 | mutsamudu
# City not found. Skipping...
# Processing Record 25 of Set 13 | cabedelo
# Processing Record 26 of Set 13 | santomera
# Processing Record 27 of Set 13 | chapais
# Processing Record 28 of Set 13 | qorveh
# Processing Record 29 of Set 13 | puerto del rosario
# Processing Record 30 of Set 13 | amarante do maranhao
# Processing Record 31 of Set 13 | manaure
# Processing Record 32 of Set 13 | viligili
# City not found. Skipping...
# Processing Record 33 of Set 13 | atar
# Processing Record 34 of Set 13 | hastings
# Processing Record 35 of Set 13 | gerede
# Processing Record 36 of Set 13 | san cristobal
# Processing Record 37 of Set 13 | xining
# Processing Record 38 of Set 13 | gazojak
# Processing Record 39 of Set 13 | niquero
# Processing Record 40 of Set 13 | beyneu
# Processing Record 41 of Set 13 | jiuquan
# Processing Record 42 of Set 13 | trairi
# Processing Record 43 of Set 13 | azad shahr
# Processing Record 44 of Set 13 | antofagasta
# Processing Record 45 of Set 13 | zhaotong
# Processing Record 46 of Set 13 | tarauaca
# Processing Record 47 of Set 13 | kelvington
# Processing Record 48 of Set 13 | ardistan
# City not found. Skipping...
# Processing Record 49 of Set 13 | nushki
# Processing Record 50 of Set 13 | huejuquilla el alto
# Processing Record 1 of Set 14 | longlac
# City not found. Skipping...
# Processing Record 2 of Set 14 | lhuntshi
# City not found. Skipping...
# Processing Record 3 of Set 14 | pemangkat
# Processing Record 4 of Set 14 | koslan
# Processing Record 5 of Set 14 | paamiut
# Processing Record 6 of Set 14 | egvekinot
# Processing Record 7 of Set 14 | high prairie
# Processing Record 8 of Set 14 | ambunti
# Processing Record 9 of Set 14 | biak
# Processing Record 10 of Set 14 | am timan
# Processing Record 11 of Set 14 | tiznit
# Processing Record 12 of Set 14 | vetapalem
# Processing Record 13 of Set 14 | khanpur
# Processing Record 14 of Set 14 | carballo
# Processing Record 15 of Set 14 | sidi ali
# Processing Record 16 of Set 14 | sao felix do xingu
# Processing Record 17 of Set 14 | anadyr
# Processing Record 18 of Set 14 | lucea
# Processing Record 19 of Set 14 | espinosa
# Processing Record 20 of Set 14 | la paz
# Processing Record 21 of Set 14 | soure
# Processing Record 22 of Set 14 | vagur
# Processing Record 23 of Set 14 | fuling
# Processing Record 24 of Set 14 | miri
# Processing Record 25 of Set 14 | maloshuyka
# City not found. Skipping...
# Processing Record 26 of Set 14 | cape coast
# Processing Record 27 of Set 14 | santa vitoria do palmar
# Processing Record 28 of Set 14 | sindor
# Processing Record 29 of Set 14 | brasilia
# Processing Record 30 of Set 14 | yerbogachen
# Processing Record 31 of Set 14 | nantai
# Processing Record 32 of Set 14 | camocim
# Processing Record 33 of Set 14 | kadiri
# Processing Record 34 of Set 14 | srednekolymsk
# Processing Record 35 of Set 14 | igarka
# Processing Record 36 of Set 14 | parthenay
# Processing Record 37 of Set 14 | champawat
# Processing Record 38 of Set 14 | sedelnikovo
# City not found. Skipping...
# Processing Record 39 of Set 14 | walvis bay
# Processing Record 40 of Set 14 | macamic
# Processing Record 41 of Set 14 | falmouth
# Processing Record 42 of Set 14 | aykhal
# Processing Record 43 of Set 14 | canmore
# Processing Record 44 of Set 14 | khor
# Processing Record 45 of Set 14 | leeuwarden
# Processing Record 46 of Set 14 | mercedes
# Processing Record 47 of Set 14 | mutoko
# Processing Record 48 of Set 14 | kabo
# Processing Record 49 of Set 14 | santa maria
# Processing Record 50 of Set 14 | ntcheu
# Processing Record 1 of Set 15 | kristiinankaupunki
# Processing Record 2 of Set 15 | elesbao veloso
# Processing Record 3 of Set 15 | shirdi
# Processing Record 4 of Set 15 | lushunkou
# City not found. Skipping...
# Processing Record 5 of Set 15 | asyut
# Processing Record 6 of Set 15 | aswan
# Processing Record 7 of Set 15 | marietta
# Processing Record 8 of Set 15 | mikkeli
# Processing Record 9 of Set 15 | marsassoum
# Processing Record 10 of Set 15 | machakos
# Processing Record 11 of Set 15 | bela vista de goias
# Processing Record 12 of Set 15 | kayanga
# Processing Record 13 of Set 15 | bandarbeyla
# Processing Record 14 of Set 15 | bosaso
# Processing Record 15 of Set 15 | kondapalle
# Processing Record 16 of Set 15 | guadalupe victoria
# Processing Record 17 of Set 15 | baculin
# Processing Record 18 of Set 15 | balimo
# City not found. Skipping...
# Processing Record 19 of Set 15 | ulundi
# Processing Record 20 of Set 15 | octeville
# Processing Record 21 of Set 15 | paracuru
# Processing Record 22 of Set 15 | veselynove
# Processing Record 23 of Set 15 | oloron-sainte-marie
# Processing Record 24 of Set 15 | alpena
# Processing Record 25 of Set 15 | nouakchott
# Processing Record 26 of Set 15 | cangucu
# Processing Record 27 of Set 15 | skagastrond
# City not found. Skipping...
# Processing Record 28 of Set 15 | butare
# Processing Record 29 of Set 15 | battle creek
# Processing Record 30 of Set 15 | tefe
# Processing Record 31 of Set 15 | berlevag
# Processing Record 32 of Set 15 | sompeta
# Processing Record 33 of Set 15 | berdigestyakh
# Processing Record 34 of Set 15 | miles city
# Processing Record 35 of Set 15 | kudahuvadhoo
# Processing Record 36 of Set 15 | margate
# Processing Record 37 of Set 15 | aleksandrovsk-sakhalinskiy
# Processing Record 38 of Set 15 | lokosovo
# Processing Record 39 of Set 15 | aden
# Processing Record 40 of Set 15 | ucluelet
# Processing Record 41 of Set 15 | medzev
# Processing Record 42 of Set 15 | godfrey
# Processing Record 43 of Set 15 | kuusamo
# Processing Record 44 of Set 15 | loandjili
# Processing Record 45 of Set 15 | kulhudhuffushi
# Processing Record 46 of Set 15 | kieta
# Processing Record 47 of Set 15 | karwar
# Processing Record 48 of Set 15 | laguna
# Processing Record 49 of Set 15 | soni
# Processing Record 50 of Set 15 | la ronge
# Processing Record 1 of Set 16 | gorontalo
# Processing Record 2 of Set 16 | isangel
# Processing Record 3 of Set 16 | bumba
# Processing Record 4 of Set 16 | ombessa
# Processing Record 5 of Set 16 | abrau-dyurso
# Processing Record 6 of Set 16 | nalut
# Processing Record 7 of Set 16 | swift current
# Processing Record 8 of Set 16 | presidencia roque saenz pena
# Processing Record 9 of Set 16 | kargil
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 700

# %% [markdown]
# ### Add the data to a new DataFrame

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City Country      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0        Jamestown      US  42.0970 -79.2353     42.01        65          90
# 1           Lashio      MM  22.9333  97.7500     69.44        54          23
# 2            Vardo      NO  70.3705  31.1107     28.40        69           0
# 3             Tara      RU  56.8944  74.3710     40.26        62          96
# 4  Arraial Do Cabo      BR -22.9661 -42.0278     74.30        82          89
# 5           Castro      BR -24.7911 -50.0119     58.21        92          75
# 6          Aksarka      RU  66.5606  67.7975     33.82        94         100
# 7     Punta Arenas      CL -53.1500 -70.9167     48.20        87          90
# 8          Ushuaia      AR -54.8000 -68.3000     50.00        71          75
# 9        Iskateley      RU  67.6803  53.1512     35.64        92         100
#
#    Wind Speed Current Description
# 0       16.11     overcast clouds
# 1        0.72          few clouds
# 2       12.66           clear sky
# 3       10.00     overcast clouds
# 4        8.14     overcast clouds
# 5        3.89       broken clouds
# 6       10.92     overcast clouds
# 7       13.80          light rain
# 8       24.16       broken clouds
# 9        7.16     overcast clouds

# %% [markdown]
# ### Export the DataFrame as a CSV file

# %%
# Create the output file (CSV).
output_data_file = "../Weather_Database/WeatherPy_Database.csv"

# Export the WeatherPy_Database into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
